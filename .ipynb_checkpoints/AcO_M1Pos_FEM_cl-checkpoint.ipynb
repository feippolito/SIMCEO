# %% [markdown]
# ### trivial_AcO_M1Pos_FEM_cl

# %%
import dos
from IPython.display import Image
path = './dos/AcO_M1Pos_FEM_cl'

# %%
# init
sim = dos.DOS(path, 20, show_timing = 2)
Image(filename=path + '/timing.png')
# Out:
# INFO:DOS:Reading config from ./dos/AcO_M1Pos_FEM_cl/dos.yaml
# INFO:DOS:New driver: M1
# INFO:M1:New input: Txyz
# INFO:M1:New input: Rxyz
# INFO:M1:New input: modes
# INFO:M1:No inputs!
# INFO:DOS:New driver: M2
# INFO:M2:New input: Txyz
# INFO:M2:New input: Rxyz
# INFO:M2:No inputs!
# INFO:DOS:New driver: wfs48
# INFO:wfs48:No inputs!
# INFO:wfs48:New output: M12_RBM
# INFO:wfs48:Output logged in!
# INFO:DOS:New driver: AcO_controller
# INFO:AcO_controller:New input: x_hat
# INFO:AcO_controller:New output: M1 TxyzRxyz
# INFO:AcO_controller:Output logged in!
# INFO:AcO_controller:New output: M2 Txyz
# INFO:AcO_controller:Output logged in!
# INFO:AcO_controller:New output: M2 Rxyz
# INFO:AcO_controller:Output logged in!
# INFO:AcO_controller:New output: M1 BM
# INFO:AcO_controller:Output logged in!
# INFO:DOS:New driver: M1Pos0
# INFO:M1Pos0:New input: TxyzRxyz
# INFO:M1Pos0:New output: M1Pos_DeltaF
# INFO:M1Pos0:Output logged in!
# INFO:DOS:New driver: FEM
# INFO:FEM:New input: OSS_Harpoint_delta_F
# INFO:FEM:New output: OSS_M1_lcl
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_Hardpoint_D
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_M1_Translation
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_M1_Rotation
# INFO:FEM:Output logged in!
# INFO:Txyz:Linked to OSS_M1_Translation from FEM
# INFO:Rxyz:Linked to OSS_M1_Rotation from FEM
# INFO:modes:Linked to M1 BM from AcO_controller
# INFO:Txyz:Linked to M2 Txyz from AcO_controller
# INFO:Rxyz:Linked to M2 Rxyz from AcO_controller
# INFO:x_hat:Linked to M12_RBM from wfs48
# INFO:TxyzRxyz:Linked to M1 TxyzRxyz from AcO_controller
# INFO:M1Pos_DeltaF:Linked to OSS_Harpoint_delta_F from FEM
# INFO:DOS:Simulation setup for a duration of 700s @ 2000Hz (1400001 steps)!
# DEBUG:DOS:Timing:M1
# DEBUG:DOS:Timing:M2
# DEBUG:DOS:Timing:wfs48
# DEBUG:DOS:Timing:AcO_controller
# DEBUG:DOS:Timing:M1Pos0
# DEBUG:DOS:Timing:FEM
# SIMCEO server received: Acknowledging connection from SIMCEO client!

# %%
sim.start()
# Out:
# INFO:DOS:Pushing configuration to server
# DEBUG:M1:Starting!
# INFO:M1:GMT
# DEBUG:M2:Starting!
# INFO:M2:GMT
# DEBUG:wfs48:Starting!
# INFO:wfs48:OP0
# DEBUG:AcO_controller:Starting!
# DEBUG:M1Pos0:Starting!
# DEBUG:FEM:Starting!
# INFO:FEM:FEM
# INFO:DOS:Initializing
# DEBUG:M1:Initializing!
# INFO:M1:None
# DEBUG:M2:Initializing!
# INFO:M2:None
# DEBUG:wfs48:Initializing!
# INFO:wfs48:None
# DEBUG:AcO_controller:Initializing!
# DEBUG:M1Pos0:Initializing!
# DEBUG:FEM:Initializing!
# INFO:FEM:None
# INFO:DOS:Running
# DEBUG:DOS:Step #0
# DEBUG:M1:Updating!
# DEBUG:M2:Updating!
# DEBUG:wfs48:Updating!
# DEBUG:wfs48:Outputing M12_RBM!
# DEBUG:wfs48:LOGGING
# DEBUG:AcO_controller:Updating!
# DEBUG:AcO_controller:u: (1, 273)
# DEBUG:AcO_controller:Outputing M1 TxyzRxyz!
# DEBUG:AcO_controller:LOGGING
# DEBUG:AcO_controller:Outputing M2 Txyz!
# DEBUG:AcO_controller:LOGGING
# DEBUG:AcO_controller:Outputing M2 Rxyz!
# DEBUG:AcO_controller:LOGGING
# DEBUG:AcO_controller:Outputing M1 BM!
# DEBUG:AcO_controller:LOGGING
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #1
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #2
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #3
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #4
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #5
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #6
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #7
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #8
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #9
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #10
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #11
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #12
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #13
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #14
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #15
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #16
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #17
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #18
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #19
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #20
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #21
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #22
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #23
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #24
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #25
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #26
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #27
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #28
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #29
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #30
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #31
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #32
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #33
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #34
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #35
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #36
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #37
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #38
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #39
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #40
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #41
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #42
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #43
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #44
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #45
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #46
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #47
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #48
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #49
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #50
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #51
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #52
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #53
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #54
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #55
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #56
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #57
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #58
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #59
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #60
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #61
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #62
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #63
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #64
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #65
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #66
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #67
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #68
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #69
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #70
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #71
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #72
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #73
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #74
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #75
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #76
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #77
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #78
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #79
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #80
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #81
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #82
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #83
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #84
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #85
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #86
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #87
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #88
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #89
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #90
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #91
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #92
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #93
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #94
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #95
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #96
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #97
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #98
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #99
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #100
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #101
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #102
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #103
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #104
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #105
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #106
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #107
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #108
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #109
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #110
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #111
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #112
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #113
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #114
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #115
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #116
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #117
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #118
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #119
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #120
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #121
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #122
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #123
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #124
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #125
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #126
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #127
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #128
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #129
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# ...
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #471
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #472
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #473
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #474
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #475
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #476
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #477
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #478
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #479
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #480
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #481
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #482
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #483
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #484
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #485
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #486
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #487
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #488
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #489
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #490
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #491
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #492
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #493
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #494
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #495
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #496
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #497
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #498
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #499
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #500
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #501
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #502
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #503
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #504
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #505
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #506
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #507
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #508
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #509
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #510
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #511
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #512
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Rotation!
# DEBUG:FEM:LOGGING
# DEBUG:DOS:Step #513
# DEBUG:M1Pos0:Updating!
# DEBUG:M1Pos0:u: (1, 42)
# DEBUG:M1Pos0:Outputing M1Pos_DeltaF!
# DEBUG:M1Pos0:LOGGING
# DEBUG:FEM:Updating!
# DEBUG:FEM:Outputing OSS_M1_lcl!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_Hardpoint_D!
# DEBUG:FEM:LOGGING
# DEBUG:FEM:Outputing OSS_M1_Translation!
# DEBUG:FEM:LOGGING
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
sim.pctComplete

# %%
sim.join()
sim.terminate()

logs = sim.logs.entries

# %%
# Save
import pickle
'''
with open('./logs/trivial_AcO_M1Pos_FEM_cl.sclogs', 'wb') as f:
    pickle.dump(sim.logs.entries, f)
    logs = sim.logs.entries
'''
# Load
'''
logs = pickle.load( open( './logs/AcO_M1Pos_FEM_cl.sclogs', "rb" ) )
''';

logs = pickle.load( open( './logs/AcO_M1Pos_FEM_cl.sclogs', "rb" ) )

# %% [markdown]
# # plot logs
# ---

# %%
import matplotlib.pyplot as plt
try:
    from jupyterthemes import jtplot
    jtplot.style()
except:
    pass

import numpy as np

duration = sim.cfg['simulation']['duration']
xticks = np.arange(0, duration + 1, 50)

logs
# Out:
# {'wfs48': {'M12_RBM': <dos.dos.Entry at 0x7ff0b83921d0>},
#  'AcO_controller': {'M1 TxyzRxyz': <dos.dos.Entry at 0x7ff0b8beb250>,
#   'M2 Txyz': <dos.dos.Entry at 0x7ff0b8bebc10>,
#   'M2 Rxyz': <dos.dos.Entry at 0x7ff0b8bebc90>,
#   'M1 BM': <dos.dos.Entry at 0x7ff0b8beb6d0>},
#  'M1PosDebug0': {'M1Pos_DeltaF': <dos.dos.Entry at 0x7ff0b8bebf10>,
#   'M1Pos_io': <dos.dos.Entry at 0x7ff0a680cb50>},
#  'FEM': {'OSS_M1_lcl': <dos.dos.Entry at 0x7ff094045990>,
#   'OSS_Hardpoint_D': <dos.dos.Entry at 0x7ff07d2c2790>},
#  'Reshape': {'M1 Txyz': <dos.dos.Entry at 0x7ff06eebe5d0>,
#   'M1 Rxyz': <dos.dos.Entry at 0x7ff06ee4bc90>}}

# %%
time_1 = logs['FEM']['OSS_M1_lcl'].timeSeries[0]
time_2000 = logs['wfs48']['M12_RBM'].timeSeries[0]
time_50000 = logs['AcO_controller']['M1 BM'].timeSeries[0]

AcO_ref = logs['AcO_controller']['M1 TxyzRxyz'].timeSeries[1]
M1Pos_in = logs['M1PosDebug0']['M1Pos_io'].timeSeries[1]
FEM_out = logs['FEM']['OSS_M1_lcl'].timeSeries[1]

# %%
AcO_ref.shape
# Out:
# (7, 6, 16)

# %%
seg = list(range(7))
Txyz = list(range(3))
Rxyz = list(range(3,6))
rbm_str = ['Tx','Ty','Tz','Rx','Ry','Rz']

for s in seg:
    fig, (ax1,ax2) = plt.subplots(2, 1, sharex=True, figsize=(18,10))
    fig.suptitle('Seg'  + str(s + 1), fontsize=16)
    for rbm in Txyz:
        ax1.plot(time_1[::20000], AcO_ref[s,rbm,:], label = str(rbm_str[rbm]))
        #ax1.plot(time_1, M1Pos_in[:, s * 6 + rbm])
        ax1.set_xticks(xticks)
        ax1.set_title('AcO_controller Txyz')
        ax1.legend()
        ax2.plot(time_1, FEM_out[:,s * 6  + rbm])
        ax2.set_title('FEM OSS_M1_lcl - Txyz')
    fig, (ax1,ax2) = plt.subplots(2, 1, sharex=True, figsize=(15,7))
    for rbm in Rxyz:
        ax1.plot(time_1[::20000], AcO_ref[s,rbm,:],label = str(rbm_str[rbm]))
        #ax1.plot(time_1, M1Pos_in[:, s * 6 + rbm])
        ax1.set_title('AcO_controller Rxyz')
        ax1.set_xticks(xticks)
        ax1.legend()
        ax2.plot(time_1, FEM_out[:,s * 6  + rbm])
        ax2.set_title('FEM OSS_M1_lcl - Rxyz')
    plt.show()

# %%
wfs = logs['wfs48']['M12_RBM'].timeSeries[1]

plt.figure(figsize = (15,7))
plt.plot(wfs)
plt.show()

# %%
BM = logs['AcO_controller']['M1 BM'].timeSeries[1]

plt.figure(figsize = (15,7))
plt.plot(BM[0,:,:].T)
plt.show()
