# %%
import dos
from IPython.display import Image
path = './dos/Integrated_HR_static'

# %%
# init
sim = dos.DOS(path, 20, show_timing = 2)
Image(filename=path + '/timing.png')
# Out:
# INFO:DOS:Reading config from ./dos/Integrated/dos.yaml
# INFO:DOS:New driver: M1
# INFO:M1:New input: Txyz
# INFO:M1:New input: Rxyz
# INFO:M1:New input: modes
# INFO:M1:No inputs!
# INFO:DOS:New driver: M2
# INFO:M2:New input: Txyz
# INFO:M2:New input: Rxyz
# INFO:M2:No inputs!
# INFO:DOS:New driver: wfs48
# INFO:wfs48:No inputs!
# INFO:wfs48:New output: M12_RBM
# INFO:wfs48:Output logged in!
# INFO:DOS:New driver: AcO_controller
# INFO:AcO_controller:New input: x_hat
# INFO:AcO_controller:New output: M1 TxyzRxyz
# INFO:AcO_controller:Output logged in!
# INFO:AcO_controller:New output: M2 Txyz
# INFO:AcO_controller:Output logged in!
# INFO:AcO_controller:New output: M2 Rxyz
# INFO:AcO_controller:Output logged in!
# INFO:AcO_controller:New output: M1 BM
# INFO:AcO_controller:Output logged in!
# INFO:DOS:New driver: M1Pos0
# INFO:M1Pos0:New input: TxyzRxyz
# INFO:M1Pos0:New output: M1Pos_DeltaF
# INFO:M1Pos0:Output logged in!
# INFO:DOS:New driver: Mount
# INFO:Mount:New input: MountFeedback_1
# INFO:Mount:New input: MountFeedback_2
# INFO:Mount:New input: MountFeedback_3
# INFO:Mount:New output: Mount_AzDrive_F
# INFO:Mount:Output logged in!
# INFO:Mount:New output: Mount_ElDrive_F
# INFO:Mount:Output logged in!
# INFO:Mount:New output: Mount_GIRDrive_F
# INFO:Mount:Output logged in!
# INFO:DOS:New driver: M1LocalControl_wBM0
# INFO:M1LocalControl_wBM0:New input: HP_F_Meas
# INFO:M1LocalControl_wBM0:New input: Bending Modes
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S1
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S2
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S3
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S4
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S5
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S6
# INFO:M1LocalControl_wBM0:New output: M1_Rel_F_S7
# INFO:DOS:New driver: M1HPloadcells0
# INFO:M1HPloadcells0:New input: M1_HP_cmd
# INFO:M1HPloadcells0:New input: M1_HP_D
# INFO:M1HPloadcells0:New output: M1_HP_F_meas
# INFO:M1HPloadcells0:Output logged in!
# INFO:DOS:New driver: FEM
# INFO:FEM:New input: OSS_AzDrive_F
# INFO:FEM:New input: OSS_ElDrive_F
# INFO:FEM:New input: OSS_GIRDrive_F
# INFO:FEM:New input: OSS_Harpoint_delta_F
# INFO:FEM:New input: M1_actuators_segment_1
# INFO:FEM:New input: M1_actuators_segment_2
# INFO:FEM:New input: M1_actuators_segment_3
# INFO:FEM:New input: M1_actuators_segment_4
# INFO:FEM:New input: M1_actuators_segment_5
# INFO:FEM:New input: M1_actuators_segment_6
# INFO:FEM:New input: M1_actuators_segment_7
# INFO:FEM:New output: OSS_AzDrive_D
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_ElDrive_D
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_GIRDrive_D
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_Hardpoint_D
# INFO:FEM:Output logged in!
# INFO:FEM:New output: Bending Modes
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_M1_Translation
# INFO:FEM:Output logged in!
# INFO:FEM:New output: OSS_M1_Rotation
# INFO:FEM:Output logged in!
# INFO:Txyz:Linked to OSS_M1_Translation from FEM
# INFO:Rxyz:Linked to OSS_M1_Rotation from FEM
# INFO:modes:Linked to Bending Modes from FEM
# INFO:Txyz:Linked to M2 Txyz from AcO_controller
# INFO:Rxyz:Linked to M2 Rxyz from AcO_controller
# INFO:x_hat:Linked to M12_RBM from wfs48
# INFO:TxyzRxyz:Linked to M1 TxyzRxyz from AcO_controller
# INFO:MountFeedback_1:Linked to OSS_AzDrive_D from FEM
# INFO:MountFeedback_2:Linked to OSS_ElDrive_D from FEM
# INFO:MountFeedback_3:Linked to OSS_GIRDrive_D from FEM
# INFO:HP_F_Meas:Linked to M1_HP_F_meas from M1HPloadcells0
# INFO:Bending Modes:Linked to M1 BM from AcO_controller
# INFO:M1_HP_cmd:Linked to M1Pos_DeltaF from M1Pos0
# INFO:M1_HP_D:Linked to OSS_Hardpoint_D from FEM
# INFO:OSS_AzDrive_F:Linked to Mount_AzDrive_F from Mount
# INFO:OSS_ElDrive_F:Linked to Mount_ElDrive_F from Mount
# INFO:OSS_GIRDrive_F:Linked to Mount_GIRDrive_F from Mount
# INFO:OSS_Harpoint_delta_F:Linked to M1Pos_DeltaF from M1Pos0
# INFO:M1_actuators_segment_1:Linked to M1_Rel_F_S1 from M1LocalControl_wBM0
# INFO:M1_actuators_segment_2:Linked to M1_Rel_F_S2 from M1LocalControl_wBM0
# INFO:M1_actuators_segment_3:Linked to M1_Rel_F_S3 from M1LocalControl_wBM0
# INFO:M1_actuators_segment_4:Linked to M1_Rel_F_S4 from M1LocalControl_wBM0
# INFO:M1_actuators_segment_5:Linked to M1_Rel_F_S5 from M1LocalControl_wBM0
# INFO:M1_actuators_segment_6:Linked to M1_Rel_F_S6 from M1LocalControl_wBM0
# INFO:M1_actuators_segment_7:Linked to M1_Rel_F_S7 from M1LocalControl_wBM0
# INFO:DOS:Simulation setup for a duration of 100s @ 2000Hz (200001 steps)!
# SIMCEO server received: Acknowledging connection from SIMCEO client!

# %%
sim.start()
# Out:
# INFO:DOS:Pushing configuration to server
# INFO:M1:GMT
# INFO:M2:GMT
# INFO:wfs48:OP0
# INFO:FEM:FEM
# INFO:DOS:Initializing
# INFO:M1:None
# INFO:M2:None
# INFO:wfs48:None
# INFO:FEM:None
# INFO:DOS:Running

# %%
sim.pctComplete
# Out:
# 99
# INFO:DOS:Terminating
# INFO:M1:GMT deleted!
# INFO:M2:GMT deleted!
# INFO:wfs48:OpticalPath deleted!
# INFO:FEM:FEM deleted
# Elapsed time: 2031.5703964233398

# %%
sim.join()
sim.terminate()

logs = sim.logs.entries
# Out:
# INFO:DOS:Terminating

# %%
# Save
import pickle


with open('./logs/Integrated_wBM.sclogs', 'wb') as f:
    pickle.dump(sim.logs.entries, f)
    logs = sim.logs.entries

"""
# Load
logs = pickle.load( open( './logs/Integrated_wBM.sclogs', "rb" ) )
""";

# %% [markdown]
# # plot logs
# ---

# %%
import matplotlib.pyplot as plt
try:
    from jupyterthemes import jtplot
    jtplot.style()
except:
    pass

import numpy as np

try:
    duration = sim.cfg['simulation']['duration']
except NameError:
    duration = logs['FEM']['OSS_AzDrive_D'].timeSeries[0][-1]
    
xticks = np.arange(0, duration + 1, duration/ 10)

logs
# Out:
# {'wfs48': {'M12_RBM': <dos.dos.Entry at 0x7f33183e7f50>},
#  'AcO_controller': {'M1 TxyzRxyz': <dos.dos.Entry at 0x7f3318379c90>,
#   'M2 Txyz': <dos.dos.Entry at 0x7f3318371410>,
#   'M2 Rxyz': <dos.dos.Entry at 0x7f3318a03350>,
#   'M1 BM': <dos.dos.Entry at 0x7f33183e7c90>},
#  'M1Pos0': {'M1Pos_DeltaF': <dos.dos.Entry at 0x7f3318371e50>},
#  'Mount': {'Mount_AzDrive_F': <dos.dos.Entry at 0x7f3318387bd0>,
#   'Mount_ElDrive_F': <dos.dos.Entry at 0x7f3318387dd0>,
#   'Mount_GIRDrive_F': <dos.dos.Entry at 0x7f33183876d0>},
#  'M1HPloadcells0': {'M1_HP_F_meas': <dos.dos.Entry at 0x7f33183678d0>},
#  'FEM': {'OSS_AzDrive_D': <dos.dos.Entry at 0x7f3318367fd0>,
#   'OSS_ElDrive_D': <dos.dos.Entry at 0x7f3318387f50>,
#   'OSS_GIRDrive_D': <dos.dos.Entry at 0x7f33183703d0>,
#   'OSS_Hardpoint_D': <dos.dos.Entry at 0x7f33183702d0>,
#   'Bending Modes': <dos.dos.Entry at 0x7f3318370290>,
#   'OSS_M1_Translation': <dos.dos.Entry at 0x7f33183704d0>,
#   'OSS_M1_Rotation': <dos.dos.Entry at 0x7f3318370910>}}

# %%
time_1 = logs['FEM']['OSS_AzDrive_D'].timeSeries[0]
time_2000 = logs['wfs48']['M12_RBM'].timeSeries[0]
time_50000 = logs['AcO_controller']['M1 BM'].timeSeries[0]

AcO_ref = logs['AcO_controller']['M1 TxyzRxyz'].timeSeries[1]
FEM_Txyz = logs['FEM']['OSS_M1_Translation'].timeSeries[1]
FEM_Rxyz = logs['FEM']['OSS_M1_Rotation'].timeSeries[1]

Mount_Az = logs['Mount']['Mount_AzDrive_F'].timeSeries[1]
Mount_El = logs['Mount']['Mount_ElDrive_F'].timeSeries[1]
Mount_GIR = logs['Mount']['Mount_GIRDrive_F'].timeSeries[1]

FEM_Az = logs['FEM']['OSS_AzDrive_D'].timeSeries[1]
FEM_El = logs['FEM']['OSS_ElDrive_D'].timeSeries[1]
FEM_GIR = logs['FEM']['OSS_GIRDrive_D'].timeSeries[1]

HP_F = logs['M1Pos0']['M1Pos_DeltaF'].timeSeries[1]

# %%
seg = list(range(7))
TRxyz = list(range(6))
rbm_str = ['Tx','Ty','Tz','Rx','Ry','Rz']
for s in seg:
    fig, ax = plt.subplots(6, 1, sharex=True, figsize=(12,15))
    fig.suptitle('Seg'  + str(s + 1), fontsize=12, horizontalalignment = 'center',
                verticalalignment = 'top')
    for rbm in TRxyz:
        ax[rbm].plot(time_1[::20000], AcO_ref[s,rbm,:], label = 'AcO')
        #ax[rbm].plot(time_1, FEM_out[:,s * 6  + rbm], label = 'FEM')
        if rbm <3:
            ax[rbm].plot(time_1, FEM_Txyz[s,rbm, :], label = 'FEM')
        else:
            ax[rbm].plot(time_1, FEM_Txyz[s,rbm - 3, :], label = 'FEM')
        ax[rbm].set_xticks(xticks)
        ax[rbm].set_title(rbm_str[rbm])
        ax[rbm].legend(loc="best")
    plt.show()

# %%
seg = list(range(7))
hp_ = list(range(6))
for s in seg:
    fig, ax = plt.subplots(6, 1, sharex=True, figsize=(12,15))
    fig.suptitle('Seg'  + str(s + 1), fontsize=12, horizontalalignment = 'center',
                verticalalignment = 'top')
    for hp in hp_:
        ax[hp].plot(time_1, HP_F[:,s * 6  + hp])
        ax[hp].set_xticks(xticks)
        ax[hp].set_title(f'Hardpoint {hp + 1} Delta F')
        #ax[hp].legend(loc="best")
    plt.show()

# %%
wfs = logs['wfs48']['M12_RBM'].timeSeries[1]

plt.figure(figsize = (15,7))
plt.plot(wfs)
plt.show()

# %%
fig, ax = plt.subplots(4,2, sharex=True, figsize=(12,12))
fig.suptitle('Mount Azimuth Forces', fontsize=16, horizontalalignment = 'center',
                verticalalignment = 'top')
for m in range(8):
    ax[m%4,m//4].plot(time_1,Mount_Az[:,m])
plt.show()

fig, ax = plt.subplots(4,2, sharex=True, figsize=(12,12))
fig.suptitle('Mount Elevation Forces', fontsize=16, horizontalalignment = 'center',
                verticalalignment = 'top')
for m in range(8):
    ax[m%4,m//4].plot(time_1,Mount_El[:,m])
plt.show()

fig, ax = plt.subplots(2,2, sharex=True, figsize=(12,6))
fig.suptitle('Mount GIR Forces', fontsize=16, horizontalalignment = 'center',
                verticalalignment = 'top')
for m in range(4):
    ax[m%2,m//2].plot(time_1,Mount_GIR[:,m])
plt.show()


fig, ax = plt.subplots(4,2, sharex=True, figsize=(12,12))
fig.suptitle('FEM Azimuth', fontsize=16, horizontalalignment = 'center',
                verticalalignment = 'top')
for m in range(8):
    ax[m%4,m//4].plot(time_1,FEM_Az[:,m])
plt.show()

fig, ax = plt.subplots(4,2, sharex=True, figsize=(12,12))
fig.suptitle('FEM Elevation', fontsize=16, horizontalalignment = 'center',
                verticalalignment = 'top')
for m in range(8):
    ax[m%4,m//4].plot(time_1,FEM_El[:,m])
plt.show()

fig, ax = plt.subplots(2,2, sharex=True, figsize=(12,6))
fig.suptitle('FEM GIR', fontsize=16, horizontalalignment = 'center',
                verticalalignment = 'top')
for m in range(4):
    ax[m%2,m//2].plot(time_1,FEM_GIR[:,m])
plt.show()

# %% [markdown]
# ### Bending Modes
# ---

# %%
BM = logs['FEM']['Bending Modes'].timeSeries[1].T

plt.figure(figsize = (15,7))
plt.plot(BM[:,:,0])
plt.show()

# %%
import scipy.io as sio
transformation_path = '../database/bendingmodes/old_consolidated_SSBM_transformation_matrices.mat'
load_args = {'squeeze_me' : True, 'mat_dtype' : True}
Q_seg = sio.loadmat(transformation_path,variable_names = ['Q_incell'],
                   **load_args)['Q_incell']
U_seg = sio.loadmat(transformation_path, variable_names = ['U_incell'],
                    **load_args)['U_incell']

# %%
import importlib
import utils
try:
    importlib.reload(utils)
except:
    pass
from utils import LargeCompute

lc = LargeCompute(onCuda = True)

# %% [markdown]
# disp_ptt_ = lc.load_disp('variables/states.dat', './dos/Integrated', int(duration) )
#
# indx = [x*742 for x in range(1,7)]
# disp_ptt = np.array(np.split(disp_ptt_, indices_or_sections = indx, axis = 0),
#                      dtype = object)

# %% [markdown]
# disp = np.empty(7, dtype = object)
# ptt = np.empty(7, dtype = object)
# for i in range(7):
#     disp[i], ptt[i] = lc.remove_ptt(Q_seg[i], disp_ptt[i])

# %%
rec_disp = np.empty(7, dtype = object)
for i in range(7):
    rec_disp[i] = lc.bm_to_disp_time(U_seg[i][:,0:27] ,BM[:,:,i].T)

# %% [markdown]
# plt.figure(figsize = (10,10))
# plt.subplot(211)
# plt.plot(rec_disp[5][200,:])
# plt.plot(disp[5][200,:], '--')
# plt.subplot(212)
# plt.plot(rec_disp[5][200,:] - disp[5][200,:])
# plt.show()

# %% [markdown]
# displacements_ptt[:,:] = np.dot(C, states)

# %% [markdown]
# indc1 = [x*742 for x in range(1,7)]
# seg_displacements_ptt_ = np.split(displacements_ptt,
#                                              indices_or_sections = indc1,
#                                              axis = 0)

# %% [markdown]
# disp_ptt = bm_utils.load_displacements('variables/states.dat',
#                                        './dos/Integrated',
#                                        int(duration))

# %%
from bendingModes_utils import bending_modes
bm_utils = bending_modes(transformation_path)

fig, ax = plt.subplots(1,2, figsize = (20, 8))
ax1, ax2 = ax
bm_utils.plot_surf(rec_disp[1:2], 0, 300000)
#bm_utils.plot_surf(rec_disp, 0, 25000)

# %%
rec_disp.shape
